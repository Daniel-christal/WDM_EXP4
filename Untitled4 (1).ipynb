# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

df = df_sample.copy() # Use the generated sample DataFrame

X = df[['Age']]

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10) # Added n_init to suppress warning

df['Cluster'] = kmeans.fit_predict(X)

print(df)

for i in range(3):
    print(f"\nCluster {i}")
    print(df[df['Cluster'] == i])
# Out:
#     Visitor_ID  Age  Cluster
# 0    Visitor_1   36        2
# 1    Visitor_2   32        0
# 2    Visitor_3   66        1
# 3    Visitor_4   42        2
# 4    Visitor_5   57        1
# 5    Visitor_6   55        1
# 6    Visitor_7   45        2
# 7    Visitor_8   73        1
# 8    Visitor_9   26        0
# 9   Visitor_10   47        2
# 10  Visitor_11   35        2
# 11  Visitor_12   18        0
# 12  Visitor_13   43        2
# 13  Visitor_14   38        2
# 14  Visitor_15   49        2
# 15  Visitor_16   23        0
# 16  Visitor_17   61        1
# 17  Visitor_18   54        1
# 18  Visitor_19   28        0
# 19  Visitor_20   56        1
# 20  Visitor_21   22        0
# 21  Visitor_22   50        2
# 22  Visitor_23   24        0
# 23  Visitor_24   22        0
# 24  Visitor_25   55        1
# 25  Visitor_26   67        1
# 26  Visitor_27   40        2
# 27  Visitor_28   47        2
# 28  Visitor_29   64        1
# 29  Visitor_30   45        2
# 30  Visitor_31   62        1
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

for i in range(3):
    cluster = df[df['Cluster'] == i]
    plt.scatter(cluster['Age'], cluster['Cluster'], label=f'Cluster {i}')

plt.scatter(
    kmeans.cluster_centers_,
    range(3),
    color='red',
    marker='X',
    s=200,
    label='Centroids'
)

plt.xlabel("Age")
plt.ylabel("Cluster")
plt.title("Visitor Segmentation using K-Means")
plt.legend()
plt.grid(True)
plt.show()
